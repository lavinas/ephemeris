# %% [markdown]
# ### Extrait fatura do cartão

# %%
from credit import ofx_extract_transaction

files = ["../files/OUROCARD_VISA_INFINITE-Ago_26.ofx", "../files/OUROCARD_VISA_INFINITE-Próxima_Fatura.ofx"]
stat_bank = ofx_extract_transaction(files, init_date="01/07/2026", end_date="31/08/2026")

for transaction in stat_bank:
    print(f"Data: {transaction['data']}, Valor: {transaction['valor']}, Descrição: {transaction['descricao']}")

print(len(stat_bank))
# Out:
# Data: 29/07/2026, Valor: -69.89, Descrição: IFD*SAO CARLOS LANCHES SAO PAULO
# Data: 30/07/2026, Valor: -12.59, Descrição: CARREFOUR BOULEVAR     SAO PAULO
# Data: 30/07/2026, Valor: -64.79, Descrição: IFD*ALRO COMERCIO DE ALSAO PAULO
# Data: 30/07/2026, Valor: -239.0, Descrição: STUDIO FERNANDO BIRKOF SAO PAULO
# Data: 31/07/2026, Valor: -27.43, Descrição: IFD*GAIA ALIMENTOS LTD SAO PAULO
# Data: 31/07/2026, Valor: -51.44, Descrição: IFD*LANCHONETE MELLO F SAO PAULO
# Data: 31/07/2026, Valor: -43.88, Descrição: IFD*LINDT SPRUNGLI BRA SAO PAULO
# Data: 31/07/2026, Valor: -39.87, Descrição: IFD*REDE INTEGRADA DE  SAO PAULO
# Data: 31/07/2026, Valor: -39.97, Descrição: IFD*ZAMP S.A.          SAO PAULO
# Data: 01/08/2026, Valor: -78.74, Descrição: 99Food *Outback - ShoppSao Paulo
# Data: 01/08/2026, Valor: -36.29, Descrição: KEETABR*BELGA DELIVERY Sao Paulo
# Data: 02/08/2026, Valor: -15.79, Descrição: IFD*GAIA ALIMENTOS LTDASAO PAULO
# Data: 02/08/2026, Valor: -63.49, Descrição: KEETABR*FAMIGLIA TEMPERSao Paulo
# Data: 03/08/2026, Valor: -19.53, Descrição: IOF ADIC ROT PF REF.07/26
# Data: 03/08/2026, Valor: -1.26, Descrição: IOF DIAR ROT PF REF.07/26
# Data: 03/08/2026, Valor: -43.54, Descrição: Kee*PALACIO DAS PIZZ   Sao Paulo
# Data: 03/08/2026, Valor: -24.99, Descrição: LOJAS AMERICANAS 566   SAO PAULO
# Data: 04/08/2026, Valor: -62.08, Descrição: 99Food *Lopes Tatuap  pSao Paulo
# Data: 04/08/2026, Valor: -59.87, Descrição: IFD*TATU RESTAURANTE S SAO PAULO
# Data: 04/08/2026, Valor: -36.39, Descrição: KEETABR*BELGA DELIVERY Sao Paulo
# Data: 05/08/2026, Valor: -46.88, Descrição: IFD*ALRO COMERCIO DE ALSAO PAULO
# Data: 05/08/2026, Valor: -64.96, Descrição: IFD*BBB TATUAPE HAMBUR SAO PAULO
# Data: 05/08/2026, Valor: -55.88, Descrição: IFD*PITAYA DELIVERY E  SAO PAULO
# Data: 05/08/2026, Valor: -44.62, Descrição: IFD*REDE INTEGRADA DE  SAO PAULO
# Data: 06/08/2026, Valor: -68.08, Descrição: IFD*OUTBACK STEAKHOUSE SAO PAULO
# 25

# %%
from credit import csv_extract_transaction

file = "../files/telma.csv"

stat_account = csv_extract_transaction(file)

for transaction in stat_account:
    print(f"Data: {transaction['data']}, Valor: {transaction['valor']}, Descrição: {transaction['descricao']}")
print(len(stat_account))
# Out:
# Data: 29/07/2026, Valor: -20.04, Descrição: ENCARGOS FINANC ROTATIVO
# Data: 29/07/2026, Valor: -69.89, Descrição: IFD*SAO CARLOS LANCHES TA
# Data: 29/07/2026, Valor: -5.13, Descrição: JUROS DE MORA
# Data: 30/07/2026, Valor: -12.59, Descrição: CARREFOUR BOULEVAR
# Data: 30/07/2026, Valor: -64.79, Descrição: IFD*ALRO COMERCIO DE ALIM
# Data: 30/07/2026, Valor: -239.0, Descrição: STUDIO FERNANDO BIRKOFF
# Data: 31/07/2026, Valor: -27.43, Descrição: IFD*GAIA ALIMENTOS LTD
# Data: 31/07/2026, Valor: -51.44, Descrição: IFD*LANCHONETE MELLO F
# Data: 31/07/2026, Valor: -43.88, Descrição: IFD*LINDT SPRUNGLI BRA
# Data: 31/07/2026, Valor: -39.87, Descrição: IFD*REDE INTEGRADA DE
# Data: 31/07/2026, Valor: -39.97, Descrição: IFD*ZAMP S.A.
# Data: 01/08/2026, Valor: -78.74, Descrição: 99Food *Outback - Shoppin
# Data: 01/08/2026, Valor: -36.29, Descrição: KEETABR*BELGA DELIVERY LT
# Data: 02/08/2026, Valor: -15.79, Descrição: IFD*GAIA ALIMENTOS LTDA
# Data: 02/08/2026, Valor: -63.49, Descrição: KEETABR*FAMIGLIA TEMPERAN
# Data: 03/08/2026, Valor: -19.53, Descrição: IOF ADIC ROT PF REF.07/26
# Data: 03/08/2026, Valor: -1.26, Descrição: IOF DIAR ROT PF REF.07/26
# Data: 03/08/2026, Valor: -43.54, Descrição: Kee*PALACIO DAS PIZZ Sao Paulo
# Data: 03/08/2026, Valor: -24.99, Descrição: LOJAS AMERICANAS 566 SAO PAULO
# Data: 04/08/2026, Valor: -80.01, Descrição: 99Food *Lopes Tatuap pen
# Data: 04/08/2026, Valor: -59.87, Descrição: IFD*TATU RESTAURANTE S
# Data: 04/08/2026, Valor: -36.39, Descrição: KEETABR*BELGA DELIVERY LT
# Data: 05/08/2026, Valor: -46.88, Descrição: IFD*ALRO COMERCIO DE ALIM
# Data: 05/08/2026, Valor: -64.96, Descrição: IFD*BBB TATUAPE HAMBUR
# Data: 05/08/2026, Valor: -55.88, Descrição: IFD*PITAYA DELIVERY E
# Data: 05/08/2026, Valor: -44.62, Descrição: IFD*REDE INTEGRADA DE
# Data: 06/08/2026, Valor: -68.08, Descrição: IFD*OUTBACK STEAKHOUSE SAO PAULO
# Data: 07/08/2026, Valor: -68.29, Descrição: IFD*CONFEITARIA VERA C
# Data: 07/08/2026, Valor: -41.49, Descrição: IFD*D.D.R. SERVICOS ALIME
# Data: 07/08/2026, Valor: -60.0, Descrição: LOJAS AMERICANAS
# Data: 07/08/2026, Valor: -26.0, Descrição: RF MELLO
# Data: 08/08/2026, Valor: -35.0, Descrição: DaniDriDelivery
# Data: 08/08/2026, Valor: -37.0, Descrição: GRUPO MADERO
# Data: 08/08/2026, Valor: -65.58, Descrição: IFD*MADERO INDUSTRIA E CO
# Data: 08/08/2026, Valor: -11.49, Descrição: OXXO VILELA GEON
# 35

# %%
from credit import transaction_diff
diff1, diff2 = transaction_diff(stat_bank, stat_account)

for transaction in diff1:
    print(f"Data: {transaction[0]}, Valor: {transaction[1]}, Descrição: {transaction[2]}")
# Out:
# Data: 04/08/2026, Valor: -62.08, Descrição: 99FOOD *

# %%
from credit import transaction_diff
diff1, diff2 = transaction_diff(stat_bank, stat_account)

for transaction in diff2:
    print(f"Data: {transaction[0]}, Valor: {transaction[1]}, Descrição: {transaction[2]}")
# Out:
# Data: 29/07/2026, Valor: -20.04, Descrição: ENCARGOS
# Data: 29/07/2026, Valor: -5.13, Descrição: JUROS DE
# Data: 04/08/2026, Valor: -80.01, Descrição: 99FOOD *
# Data: 07/08/2026, Valor: -68.29, Descrição: IFD*CONF
# Data: 07/08/2026, Valor: -41.49, Descrição: IFD*D.D.
# Data: 07/08/2026, Valor: -60.0, Descrição: LOJAS AM
# Data: 07/08/2026, Valor: -26.0, Descrição: RF MELLO
# Data: 08/08/2026, Valor: -35.0, Descrição: DANIDRID
# Data: 08/08/2026, Valor: -37.0, Descrição: GRUPO MA
# Data: 08/08/2026, Valor: -65.58, Descrição: IFD*MADE
# Data: 08/08/2026, Valor: -11.49, Descrição: OXXO VIL
