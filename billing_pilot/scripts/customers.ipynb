# %% [markdown]
# ## Clientes
#
# Rotinas de manutenção de clientes

# %% [markdown]
# ### inserir clientes iniciais

# %%
import pandas as pd

clients = '''
Ana Flavia de Andrade da Silva,ana_flavia,,andrade.af22@gmail.com,
Camila Trevizani Merigui,camila,,camilamerighi@hotmail.com,
Timbere Serpa Nogueira,timbere,368.683.338-70,timbere.nog@gmail.com,
Solange Severina Lopes (Sophia),solange,165.191.238-62 ,solangeslopes@yahoo.com.br,
Viviane Ferreira Cerqueira ,viviane,112.231.236-93,vivianefcerqueira@gmail.com,
Gisele Alves Guimaraes (Nina),gisele,629.942.635-72,gisadudy@yahoo.com.br,
Caroline Nascimento de Souza,caroline,325.913.338-07,krol.nascimento85@gmail.com,
Juliana Maria Luzzi Franco Ribeiro,juliana,282.017.818-99,jmlfr@uol.com.br,
Rodolpho dos Santos Moraes,rodolpho,119.082.487-69,moraes.rodolpho@gmail.com,
Andrea Silva ,andrea,300.700.538-80,andrea-psico@hotmail.com,
Miriam Silva,miriam,028.379.978-11,miriam.silva09@gmail.com,
Fabio Cabrini,fabio,234.480.128-66, fafe77@yahoo.com,
Camila Pereira Pinto,camila_pereira,374.904.058-31,camila.pp6@gmail.com,
Lucas Gagliato Uriel Militao,lucas,470.527.008-83,lucasgagliatoum@hotmail.com,
Alessandra Dias Galassi,alessandra,152.719.708-50,alegalassi7@gmail.com,
Jéssica Martins Rodrigues da Silva ,jessica, 480.898.918-29, jessicamartins2807@gmail.com,
Rodrigo Brito,rodrigo,271.943.998-30 ,britors@live.com,
'''

df = pd.DataFrame([x.split(',') for x in clients.strip().split('\n')],
                  columns=['name', 'username', 'document', 'email', 'whatsapp'])
print(df)
# Out:
#                                    name        username         document  \
# 0        Ana Flavia de Andrade da Silva      ana_flavia
# 1              Camila Trevizani Merigui          camila
# 2                Timbere Serpa Nogueira         timbere   368.683.338-70
# 3       Solange Severina Lopes (Sophia)         solange  165.191.238-62
# 4           Viviane Ferreira Cerqueira          viviane   112.231.236-93
# 5         Gisele Alves Guimaraes (Nina)          gisele   629.942.635-72
# 6          Caroline Nascimento de Souza        caroline   325.913.338-07
# 7    Juliana Maria Luzzi Franco Ribeiro         juliana   282.017.818-99
# 8            Rodolpho dos Santos Moraes        rodolpho   119.082.487-69
# 9                         Andrea Silva           andrea   300.700.538-80
# 10                         Miriam Silva          miriam   028.379.978-11
# 11                        Fabio Cabrini           fabio   234.480.128-66
# ...

# %% [markdown]
# ### Inserir um cliente
#
# Inserir  para geração de invoices e outros

# %%
from lib.customers import create_customer

nome = 'Paulo Celso Lavinas Barbosa'
apelido = 'lavinas5'
documento = '123.456.789-01'
email = 'lavinas@gmail.com'
wapp = '11999999999'
print(create_customer(nome, apelido, documento, email, wapp))
# Out:
# Cliente com documento 123.456.789-01 já existe

# %% [markdown]
# ## Consultar clientes ativos
#
# Consultar todos os clientes ativos

# %%
from lib.customers import find_active_customers

customers = find_active_customers()
print(customers.to_markdown(index=False))
# Out:
# |   id | nome                        | apelido   | documento      | email             |    whatsapp |
# |-----:|:----------------------------|:----------|:---------------|:------------------|------------:|
# |    1 | Paulo Celso Lavinas Barbosa | lavinas4  | 123.456.789-03 | lavinas@gmail.com | 11999999999 |
# |    2 | Paulo Celso Lavinas Barbosa | lavinas5  | 123.456.789-01 | lavinas@gmail.com | 11999999999 |
