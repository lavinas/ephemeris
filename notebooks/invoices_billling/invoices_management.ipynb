# %% [markdown]
# ## Invoices

# %% [markdown]
# ### Consultar Invoices

# %%
from invoices_management import get

vendor = 'estudio_amelia'
customer = '' # - todos
invoicing = '2026-09' # 'YYYY-MM-DD' ou ''
due = '' # 'YYYY-MM-DD' ou ''
payment = '' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi paga
email_sent = '' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi enviada por email
whatsapp_sent = '' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi enviada por whatsapp
email_receipt = '' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi recebida por email
whatsapp_receipt = '' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi recebida por whatsapp
tax = '' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi enviada para a contabilidade
cancellation = 'null' # 'YYYY-MM-DD' ou '' ou 'null' ou 'not null' - para os casos em que a fatura ainda não foi cancelada

invoices, qtty, total_amount, paid_amount = get(vendor, customer, invoicing, due, payment, email_sent, whatsapp_sent, email_receipt, whatsapp_receipt, tax, cancellation)
print(invoices)
print(f'Number of invoices: {qtty}')
print(f'Total amount: {total_amount}')
print(f'Paid amount: {paid_amount}')
# Out:
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |   id | customer            |   amount | invoicing   | due        | payment    | email_sent   | whatsapp_sent   | email_receipt   | whatsapp_receipt   | tax   | cancellation   | notes   | items                                                                    |
# +======+=====================+==========+=============+============+============+==============+=================+=================+====================+=======+================+=========+==========================================================================+
# |  617 | ana_flavia          |      220 | 2026-09-04  | 2026-09-07 | 2026-09-21 | 2026-09-04   | -               | 2026-09-23      | -                  | -     | -              | -       | aulas de canto de 60 minutos em agosto de 2026 (qtty: 2, price: 110)     |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  618 | camila_merigui      |      490 | 2026-09-04  | 2026-09-07 | 2026-09-15 | 2026-09-04   | -               | 2026-09-17      | -                  | -     | -              | -       | aulas de canto de 60 minutos em agosto de 2026 (qtty: 3, price: 98)      |
# |      |                     |          |             |            |            |              |                 |                 |                    |       |                |         | aulas de piano de 60 minutos em agosto de 2026 (qtty: 2, price: 98)      |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  619 | carol_teclarte      |      392 | 2026-09-04  | 2026-09-07 | 2026-09-08 | 2026-09-04   | -               | 2026-09-05      | -                  | -     | -              | -       | aulas de canto de 45 minutos em setembro de 2026 (qtty: 4, price: 98)    |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  629 | fabio               |      110 | 2026-09-07  | 2026-09-08 | 2026-09-08 | -            | -               | 2026-09-07      | -                  | -     | -              | -       | aula de canto 60 minutos em 07/09/2026 (qtty: 1, price: 110)             |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  628 | gabrielle_agostinho |      150 | 2026-09-05  | 2026-09-05 | 2026-09-08 | 2026-09-05   | -               | 2026-09-07      | -                  | -     | -              | -       | aulas de canto 60 minutos prevista para 07/09/2026 (qtty: 1, price: 150) |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  633 | gabrielle_agostinho |      240 | 2026-09-12  | 2026-09-21 | 2026-09-18 | 2026-09-17   | -               | 2026-09-19      | -                  | -     | -              | -       | aulas de canto de 60 minutos em setembro de 2026 (qtty: 2, price: 120)   |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  620 | giovanna_boni       |      220 | 2026-09-04  | 2026-09-21 | 2026-09-23 | 2026-09-17   | -               | 2026-09-24      | -                  | -     | -              | -       | aulas de canto de 60 minutos em agosto de 2026 (qtty: 2, price: 110)     |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  621 | julia_(florida)     |      392 | 2026-09-04  | 2026-09-21 | 2026-09-21 | 2026-09-17   | -               | 2026-09-20      | -                  | -     | -              | -       | aulas de canto de 45 minutos em agosto de 2026 (qtty: 4, price: 98)      |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  622 | juliana_franco      |      440 | 2026-09-04  | 2026-09-15 | 2026-09-14 | 2026-09-14   | -               | 2026-09-15      | -                  | -     | -              | -       | aulas de canto de 60 minutos em agosto de 2026 (qtty: 4, price: 110)     |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  623 | miriam              |      220 | 2026-09-04  | 2026-09-10 | 2026-09-15 | 2026-09-08   | -               | 2026-09-17      | -                  | -     | -              | -       | aulas de canto de 60 minutos em agosto de 2026 (qtty: 2, price: 110)     |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  632 | nicolas_neri        |      280 | 2026-09-08  | 2026-09-08 | 2026-09-08 | 2026-09-08   | -               | 2026-09-08      | -                  | -     | -              | -       | aulas de canto de 30 minutos em setembro de 2026 (qtty: 4, price: 70)    |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  624 | rui_miranda         |      240 | 2026-09-04  | 2026-09-10 | 2026-09-24 | 2026-09-08   | -               | 2026-09-24      | -                  | -     | -              | -       | aulas de canto de 60 minutos em setembro de 2026 (qtty: 2, price: 120)   |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  625 | sophia_lopes        |      360 | 2026-09-04  | 2026-09-15 | 2026-09-15 | 2026-09-14   | -               | 2026-09-15      | -                  | -     | -              | -       | aulas de canto de 30 minutos em agosto de 2026 (qtty: 2, price: 60)      |
# |      |                     |          |             |            |            |              |                 |                 |                    |       |                |         | aulas de canto de 60 minutos em agosto de 2026 (qtty: 2, price: 120)     |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  626 | timbere_nogueira    |      440 | 2026-09-04  | 2026-09-27 | -          | 2026-09-23   | -               | -               | -                  | -     | -              | -       | aulas de canto de 60 minutos em setembro de 2026 (qtty: 4, price: 110)   |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# |  627 | viviane_cerqueira   |      440 | 2026-09-04  | 2026-09-15 | -          | 2026-09-14   | -               | -               | -                  | -     | -              | -       | aulas de canto de 60 minutos em setembro de 2026 (qtty: 4, price: 110)   |
# +------+---------------------+----------+-------------+------------+------------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+--------------------------------------------------------------------------+
# Number of invoices: 15
# Total amount: 4634.0
# Paid amount: 3754.0

# %% [markdown]
# ### Vencidas

# %%
from invoices_management import get_overdue

vendor = 'estudio_amelia'
overdue_invoices, qtty, total_amount, paid_amount = get_overdue(vendor)
print(overdue_invoices)
print(f"Quantity: {qtty}, Total Amount: {total_amount}, Paid Amount: {paid_amount}")
# Out:
# +------+-------------------+----------+-------------+---------------------+-----------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+---------------------------------------------------------------------------------------+-----------+
# |   id | customer          |   amount | invoicing   | due                 | payment   | email_sent   | whatsapp_sent   | email_receipt   | whatsapp_receipt   | tax   | cancellation   | notes   | items                                                                                 | overdue   |
# +======+===================+==========+=============+=====================+===========+==============+=================+=================+====================+=======+================+=========+=======================================================================================+===========+
# |  614 | andressa_lino     |       70 | 2026-08-20  | 2026-08-27 00:00:00 | -         | 2026-08-20   | -               | -               | -                  | -     | -              | -       | hora adicional de aulas de canto de 30 minutos em agosto de 2026 (qtty: 1, price: 70) | True      |
# +------+-------------------+----------+-------------+---------------------+-----------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+---------------------------------------------------------------------------------------+-----------+
# |  627 | viviane_cerqueira |      440 | 2026-09-04  | 2026-09-15 00:00:00 | -         | 2026-09-14   | -               | -               | -                  | -     | -              | -       | aulas de canto de 60 minutos em setembro de 2026 (qtty: 4, price: 110)                | True      |
# +------+-------------------+----------+-------------+---------------------+-----------+--------------+-----------------+-----------------+--------------------+-------+----------------+---------+---------------------------------------------------------------------------------------+-----------+
# Quantity: 2, Total Amount: 510.0, Paid Amount: 0.0

# %% [markdown]
# ### Faturamento

# %%
from invoices_management import invoicing_graph

vendor = 'estudio_amelia'
inicio = '2026-01-01'
fim = '2026-12-31'

plt = invoicing_graph(vendor, inicio, fim)

# %% [markdown]
# ### Inserir invoice

# %%
from invoices_management import insert

vendor = 'estudio_amelia'
customer = 'gabrielle_agostinho' #
invoicing = '2026-09-12' # 'YYYY-MM-DD'
due = '2026-09-20' # 'YYYY-MM-DD'
payment = '' # 'YYYY-MM-DD' ou ''
cancellation = '' # 'YYYY-MM-DD' ou ''
notes = '' # 'texto' ou ''

items = [
    {'description': 'aulas de canto de 60 minutos em setembro de 2026', 'quantity': 2, 'price': 120}
]
invoices = insert(vendor, customer, invoicing, due, payment, cancellation, notes, items)
print(invoices)
# Out:
# success - Invoice created successfully

# %% [markdown]
# ### Registrar pagamento

# %%
from invoices_management import get_paid

vendor = 'estudio_amelia'
customer = 'rui_miranda' #
invoicing = '2026-09' # 'YYYY-MM-DD' ou ''
payment_date = '2026-09-24'
payment_value = 240.00

resp = get_paid(vendor, customer, invoicing, payment_value, payment_date)
print(resp)
# Out:
# Pagamento registrado e enviado com sucesso.

# %% [markdown]
# ### Alterar invoice

# %%
from invoices_management import update

vendor = 'estudio_amelia' # coloque o nome do fornecedor que deseja atualizar a fatura
id = 633    # coloque o id da fatura que deseja atualizar
invoicing = '' # 'YYYY-MM-DD' ou ''
due = '2026-09-21' # 'YYYY-MM-DD' ou ''
payment = '' # 'YYYY-MM-DD' ou ''
email_sent = '' # 'YYYY-MM-DD' ou ''
whatsapp_sent = '' # 'YYYY-MM-DD' ou ''
cancellation = '' # 'YYYY-MM-DD' ou ''
tax = '' # 'YYYY-MM-DD' ou ''

invoices = update(vendor, id, invoicing, due, payment, email_sent, whatsapp_sent, tax, cancellation)
print(invoices)
# Out:
# success - Invoice updated successfully

# %% [markdown]
# ### Send Bill

# %%
from invoices_management import send_bill

vendor = 'estudio_amelia'
invoice_id = 626
doc = 0 # 0 - invoice, 1 - recibo
email = ''

result = send_bill(vendor, invoice_id, doc, email)
print(result)
# Out:
# success -

# %% [markdown]
# ### Save Bill

# %%
from invoices_management import save_bill

vendor = 'estudio_amelia'
invoice_id = 620
doc = 0
path = '../files/'


result = save_bill(vendor, invoice_id, doc, path)
print(result)
# Out:
# Arquivo salvo com sucesso em: ../files/2026-09-21-2026-09-04-giovanna_boni-invoice.pdf

# %% [markdown]
# ### Insert CSV

# %%
from invoices_management import insert_csv

vendor = 'estudio_amelia'
csv_file = '../files/invoices-2026-09.csv'

responses = insert_csv(vendor, csv_file)    
for line, text in enumerate(responses, start=1):
    print(f'{line} - {text}')
print(f'Total: {len(responses)}')
# Out:
# 1 - Payload '{'vendor': 'estudio_amelia', 'customer': 'ana_flavia', 'invoicing': '2026-09-04', 'due': '2026-09-07', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em agosto de 2026', 'quantity': 2, 'price': 110.0}]}'.Resposta: success - Invoice created successfully
# 2 - Payload '{'vendor': 'estudio_amelia', 'customer': 'camila_merigui', 'invoicing': '2026-09-04', 'due': '2026-09-07', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em agosto de 2026', 'quantity': 3, 'price': 98.0}, {'description': 'aulas de piano de 60 minutos em agosto de 2026', 'quantity': 2, 'price': 98.0}]}'.Resposta: success - Invoice created successfully
# 3 - Payload '{'vendor': 'estudio_amelia', 'customer': 'carol_teclarte', 'invoicing': '2026-09-04', 'due': '2026-09-07', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 45 minutos em setembro de 2026', 'quantity': 4, 'price': 98.0}]}'.Resposta: success - Invoice created successfully
# 4 - Payload '{'vendor': 'estudio_amelia', 'customer': 'giovanna_boni', 'invoicing': '2026-09-04', 'due': '2026-09-21', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em agosto de 2026', 'quantity': 2, 'price': 110.0}]}'.Resposta: success - Invoice created successfully
# 5 - Payload '{'vendor': 'estudio_amelia', 'customer': 'julia_(florida)', 'invoicing': '2026-09-04', 'due': '2026-09-21', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 45 minutos em agosto de 2026', 'quantity': 4, 'price': 98.0}]}'.Resposta: success - Invoice created successfully
# 6 - Payload '{'vendor': 'estudio_amelia', 'customer': 'juliana_franco', 'invoicing': '2026-09-04', 'due': '2026-09-15', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em agosto de 2026', 'quantity': 4, 'price': 110.0}]}'.Resposta: success - Invoice created successfully
# 7 - Payload '{'vendor': 'estudio_amelia', 'customer': 'miriam', 'invoicing': '2026-09-04', 'due': '2026-09-10', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em agosto de 2026', 'quantity': 2, 'price': 110.0}]}'.Resposta: success - Invoice created successfully
# 8 - Payload '{'vendor': 'estudio_amelia', 'customer': 'rui_miranda', 'invoicing': '2026-09-04', 'due': '2026-09-10', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em setembro de 2026', 'quantity': 2, 'price': 120.0}]}'.Resposta: success - Invoice created successfully
# 9 - Payload '{'vendor': 'estudio_amelia', 'customer': 'sophia_lopes', 'invoicing': '2026-09-04', 'due': '2026-09-15', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 30 minutos em agosto de 2026', 'quantity': 2, 'price': 60.0}, {'description': 'aulas de canto de 60 minutos em agosto de 2026', 'quantity': 2, 'price': 120.0}]}'.Resposta: success - Invoice created successfully
# 10 - Payload '{'vendor': 'estudio_amelia', 'customer': 'timbere_nogueira', 'invoicing': '2026-09-04', 'due': '2026-09-27', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em setembro de 2026', 'quantity': 4, 'price': 110.0}]}'.Resposta: success - Invoice created successfully
# 11 - Payload '{'vendor': 'estudio_amelia', 'customer': 'viviane_cerqueira', 'invoicing': '2026-09-04', 'due': '2026-09-15', 'payment': '', 'cancellation': '', 'notes': '', 'items': [{'description': 'aulas de canto de 60 minutos em setembro de 2026', 'quantity': 4, 'price': 110.0}]}'.Resposta: success - Invoice created successfully
# Total: 11
