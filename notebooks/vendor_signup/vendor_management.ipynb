# %% [markdown]
# ## Empresas
#
# Rotinas de manutenção de empresas

# %% [markdown]
# ### Consultar Empresas

# %%
import vendor_management as vendor
# parametros de configuração
nickname = "" # obrigatório
legal_name = ""
trading_name = ""
document = "27928875000104"
email = ""
whatsapp = ""

user_list, user_count = vendor.get(nickname, legal_name, trading_name, document, email, whatsapp)

print(user_list)
print(f"Total de empresas: {user_count}")
# Out:
# Nenhum usuario encontrado.
# Total de empresas: 0

# %% [markdown]
# ### Inserir um empresas

# %%
import vendor_management as vendor

# parametros de configuração

nickname = ""
legal_name = ""



vendor = 'estudio_amelia'
name = 'Paulo User'
password = "pwd22Adm*"
username = 'paulo_user'
email = 'lavinas@gmail.com'
whatsapp = '(11)980876112'

print(vendor.insert(vendor, username, password, name, email, whatsapp))

# %% [markdown]
# ## Atualizar um usuario

# %%
import vendor_management as vendor

# parametros de configuração
vendor = "estudio_amelia"
username = "paulo_user"
password = ""
name = ""
email = ""
whatsapp = ""
status = "1" # 1 - ativo; 0 - inativo

# "alegalassi7@gmail.com"

print(vendor.update(1, vendor, username, password, name, email, whatsapp, status))
