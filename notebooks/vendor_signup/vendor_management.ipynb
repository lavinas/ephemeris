# %% [markdown]
# ## Empresas
#
# Rotinas de manutenção de empresas

# %% [markdown]
# ### Consultar Empresas

# %%
import vendor_management as vendor
# parametros de configuração
nickname = "" # obrigatório
legal_name = ""
trading_name = ""
document = ""
email = ""
whatsapp = ""

user_list, user_count = vendor.get(nickname, legal_name, trading_name, document, email, whatsapp)

print(user_list)
print(f"Total de empresas: {user_count}")
# Out:
# +------+----------------+-------------------------------------------------------+------------------------+--------------------+-----------------+-----------------+------------------+------------------+--------------------+------------------------------+------------+-----------------+---------------------------------+-----------------+------------+---------------+-------------+---------------------------------+
# |   id | nickname       | legal_name                                            | trading_name           | document           | tax_document    | account_bank    |   account_agency | account_number   | pix_token          | pix_name                     | pix_city   | logo_name       | email                           | whatsapp        |   last_rps | smtp_host     |   smtp_port | smtp_user                       |
# ...

# %% [markdown]
# ### Inserir um empresas

# %%
import vendor_management as vendor

# parametros de configuração
nickname = 'empresa1'
legal_name = 'legal'
trading_name = 'trading'
document = '95.210.388/0001-61'
tax_document = '321321321312232'
account_bank = '001'
account_agency = '9299'
account_number = '2223232-2'
pix_token = 'pix_token'
pix_name = 'Empresa x'
pix_city = 'Sao Paulo'
logo_name = 'logo.png'
email = 'teste@test.com.be'
whatsapp = '11980876112'
last_rps = 100
smtp_host = 'localhost'
smtp_port = 3309
smtp_user = 'use_localhost'
smtp_password = 'pass_word'

print(vendor.insert(nickname, legal_name, trading_name, document, tax_document, account_bank, account_agency, account_number, pix_token, pix_name, pix_city, logo_name, email, whatsapp, last_rps, smtp_host, smtp_port, smtp_user, smtp_password))
# Out:
# success - Saved successfully

# %% [markdown]
# ## Atualizar um usuario

# %%
import vendor_management as vendor

# parametros de configuração
vendor = "estudio_amelia"
username = "paulo_user"
password = ""
name = ""
email = ""
whatsapp = ""
status = "1" # 1 - ativo; 0 - inativo

# "alegalassi7@gmail.com"

print(vendor.update(1, vendor, username, password, name, email, whatsapp, status))
