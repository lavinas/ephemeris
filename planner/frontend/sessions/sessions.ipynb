# %% [markdown]
# ## Gestão de sessões

# %% [markdown]
# ### Listar Sessões

# %%
from sessions import get

nickname = ""
date_start = ""
date_end = ""
minutes = ""
service = ""
status = ""
comments = ""

result = get(nickname, date_start, date_end, minutes, service, status, comments)
print(result)
# Out:
# +--------------+------------+------------+-----------+-----------+------------+------------+
# |   session_id | nickname   | date       |   minutes | status    | service    | comments   |
# +==============+============+============+===========+===========+============+============+
# |            3 | jose_silva | 2026-01-01 |        60 | realizada | aula/canto | nenem      |
# +--------------+------------+------------+-----------+-----------+------------+------------+

# %% [markdown]
# ### Criar Sessão

# %%
from sessions import create

nickname = "jose_silva"
date = "2026-01-01"
minutes = 60
service = "aula/canto"
status = "realizada"
comments = "nenem"

result = create(nickname, date, minutes, service, status, comments)
print(result)
# Out:
# Session created successfully with ID: 3

# %% [markdown]
# ### Deletar Sessão

# %%
from sessions import delete

id = 2
result = delete(id)
print(result)
# Out:
# Session with ID: 2 deleted successfully.
