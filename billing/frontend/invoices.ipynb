# %% [markdown]
# ## Invoices

# %% [markdown]
# ### Consultar Invoices

# %%
from invoices import get

vendor = 'estudio_amelia'
customer = ''
invoicing = '' # 'YYYY-MM-DD' ou ''
due = '' # 'YYYY-MM-DD' ou ''
payment = '' # 'YYYY-MM-DD' ou ''
email_sent = '' # 'YYYY-MM-DD' ou ''
whatsapp_sent = '' # 'YYYY-MM-DD' ou ''
tax = '' # 'YYYY-MM-DD' ou ''

invoices = get(vendor, customer, invoicing, due, payment, email_sent, whatsapp_sent, tax)
print(invoices)
# Out:
# +------+------------+----------+-------------+------------+------------+--------------+-----------------+-------+-----------+-----------+---------------+------------+---------+
# |   id | customer   |   amount | invoicing   | due        | payment    | email_sent   | whatsapp_sent   | tax   | notes     |   item_id | description   |   quantity |   price |
# +======+============+==========+=============+============+============+==============+=================+=======+===========+===========+===============+============+=========+
# |    1 | test       |      200 | 2026-01-01  | 2026-01-01 | -          | -            | -               | -     | -         |         1 | test          |          1 |     100 |
# +------+------------+----------+-------------+------------+------------+--------------+-----------------+-------+-----------+-----------+---------------+------------+---------+
# ...

# %% [markdown]
# ### Inserir invoice

# %%
from invoices import insert

vendor = 'estudio_amelia'
customer = 'test'
invoicing = '2026-01-01' # 'YYYY-MM-DD'
due = '2026-01-01' # 'YYYY-MM-DD'
payment = '2026-01-02'
notes = 'teeeeteet'

items = [
    {'description': 'test', 'quantity': 1, 'price': 100},
    {'description': 'test2', 'quantity': 2, 'price': 50}
]
invoices = insert(vendor, customer, invoicing, due, payment, notes, items)
print(invoices)
# Out:
# success - Invoice created successfully
