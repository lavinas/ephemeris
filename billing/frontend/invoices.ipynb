# %% [markdown]
# ## Invoices

# %% [markdown]
# ### Consultar Invoices

# %%
from invoices import get

vendor = 'estudio_amelia'
customer = ''
invoicing = '' # 'YYYY-MM-DD' ou ''
due = '' # 'YYYY-MM-DD' ou ''
email_sent = '' # 'YYYY-MM-DD' ou ''
whatsapp_sent = '' # 'YYYY-MM-DD' ou ''
tax = '' # 'YYYY-MM-DD' ou ''

invoices = get(vendor, customer, invoicing, due, email_sent, whatsapp_sent, tax)
print(invoices)
# Out:
# +------+------------+----------+-------------+------------+--------------+-----------------+-------+---------+-----------+---------------+------------+---------+
# |   id | customer   |   amount | invoicing   | due        | email_sent   | whatsapp_sent   | tax   | notes   |   item_id | description   |   quantity |   price |
# +======+============+==========+=============+============+==============+=================+=======+=========+===========+===============+============+=========+
# |    1 | test       |       11 | 2026-01-01  | 2026-01-01 | -            | -               | -     | -       |         1 | xxx           |         10 |     1.1 |
# +------+------------+----------+-------------+------------+--------------+-----------------+-------+---------+-----------+---------------+------------+---------+
# |    2 | test       |       11 | 2026-01-01  | 2026-01-01 | -            | -               | -     | -       |         2 | xxx           |         10 |     1.1 |
# +------+------------+----------+-------------+------------+--------------+-----------------+-------+---------+-----------+---------------+------------+---------+
