# %% [markdown]
# ## Emissions

# %% [markdown]
# ### Send emission

# %%
from emission import send

vendor = 'estudio_amelia' # obrigatório
start = '2026-03-01'
end   = '2026-05-31'
emission_date = '2026-06-28'

resp = send(vendor, start, end, emission_date)
print(resp)
# Out:
# success - Emission sent successfully
