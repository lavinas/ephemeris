# %% [markdown]
# ## Emissions

# %% [markdown]
# ### Send emission

# %%
from emission import send

vendor = 'estudio_amelia' # obrigatório
start = '2026-03-01' # obrigatório
end   = '2026-07-05' # obrigatório
emission_date = '2026-07-05' # obrigatório

resp = send(vendor, start, end, emission_date)
print(resp)
# Out:
# success - Emission sent successfully - id: 58 - qtde: 65 - valor: 20216

# %% [markdown]
# ### Receive reponse

# %%
from emission import receive

vendor = 'estudio_amelia' # obrigatório
emission_id = 58 # obrigatório
source = './files/NFSe_RPS_57278881_20260705_20260705.csv' # obrigatório

resp = receive(vendor, emission_id, source)
print(resp)
# Out:
# success - Emission received successfully - id: 58 - qtde: 65 - valor: 20216
