# %% [markdown]
# ## Tax

# %% [markdown]
# ### Generate

# %%
from tax import generate

vendor = 'estudio_amelia' # obrigatório
start = '2026-05-01' # obrigatório
end   = '2026-07-31' # obrigatório
emission_date = '2026-08-09' # obrigatório
path = '../files/'

resp = generate(vendor, start, end, emission_date, path)
print(resp)
# Out:
# success - Emission sent successfully - id: 95 - qtde: 15 - valor: 4094

# %% [markdown]
# ### Receive clear

# %%
from tax import clear

vendor = 'estudio_amelia' # obrigatório
emission_id = 95 # obrigatório
source = '../files/NFSe_E_57278881_20260801_20260831.csv' # obrigatório

resp = clear(vendor, emission_id, source)
print(resp)
# Out:
# 200 - success - Emission received successfully
