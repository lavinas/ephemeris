# %% [markdown]
# ## Tax

# %% [markdown]
# ### Generate

# %%
from tax import generate

vendor = 'estudio_amelia' # obrigatório
start = '2026-05-01' # obrigatório
end   = '2026-07-31' # obrigatório
emission_date = '2026-08-09' # obrigatório
path = '../files/'

resp = generate(vendor, start, end, emission_date, path)
print(resp)
# Out:
# success - Emission sent successfully - id: 95 - qtde: 15 - valor: 4094

# %% [markdown]
# ### Receive reponse

# %%
from tax import receive

vendor = 'estudio_amelia' # obrigatório
emission_id = 58 # obrigatório
source = './files/NFSe_RPS_57278881_20260705_20260705.csv' # obrigatório

resp = receive(vendor, emission_id, source)
print(resp)
# Out:
# success - Emission received successfully - id: 58 - qtde: 65 - valor: 20216
