# %% [markdown]
# ## Clientes
#
# Rotinas de manutenção de clientes

# %% [markdown]
# ### Conultar clientes

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
status = -1 # 1 - ativos; 0 - inativos; -1 - todos
nickname = ''
name = ''
document = ''
email = ''
whatsapp = ''

print(customers.get(vendor, status, nickname, name, document, email, whatsapp))
# Out:
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |   id | name           | nickname      |   status | document       | email                   | whatsapp        |
# +======+================+===============+==========+================+=========================+=================+
# |    1 | Paulo          | test          |        1 | 044.179.328-24 | lavinas@gmail.com       | (11)98087-6112  |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |    2 | Paulo          | test2         |        1 | 460.832.090-48 | lavinas@gmail.com       | (11)98087-6112  |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |    3 | Maria da Silva | maria_silva   |        1 | 336.871.860-67 | maria.silva@example.com | 13980888788     |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |    4 | Maria da Silva | maria_silva_2 |        1 | 766.273.780-27 | maria.silva@example.com | 13980888788     |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |    5 | Maria da Silva | maria_silva_3 |        1 | 384.503.880-23 | maria.silva@example.com | (13) 98088-8788 |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |    6 | Maria da Silva | maria_silva_4 |        1 | 020.635.650-15 | maria.silva@example.com | (13) 98088-8788 |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+

# %% [markdown]
# ### Inserir um cliente

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
name = 'Maria da Silva'
nickname = 'maria_silva_4'
document = '02063565015'
email = 'maria.silva@example.com'
whatsapp = '13980888788'

print(customers.insert(vendor, nickname, name, document, email, whatsapp))
# Out:
# success - Customers created successfully
