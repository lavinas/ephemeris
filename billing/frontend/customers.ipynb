# %% [markdown]
# ## Clientes
#
# Rotinas de manutenção de clientes

# %% [markdown]
# ### Consultar clientes

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
status = "1" # 1 - ativos; 0 - inativos; "" - todos, 
nickname = ''
name = ''
document = ''
email = ''
whatsapp = ''

customers_list, customers_count = customers.get(vendor, status, nickname, name, document, email, whatsapp)

print(customers_list)
print(f"Total de clientes: {customers_count}")
# Out:
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   id | name                               | nickname       |   status | document       | email                        |
# +======+====================================+================+==========+================+==============================+
# |   16 | Alessandra Dias Galassi            | alessandra     |        1 | 152.719.708-50 | alegalassi7@gmail.com        |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    3 | Ana Flavia de Andrade da Silva     | ana_flavia     |        1 | -              | andrade.af22@gmail.com       |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   11 | Andrea Silva                       | andrea         |        1 | 300.700.538-80 | andrea-psico@hotmail.com     |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    4 | Camila Trevizani Merigui           | camila         |        1 | -              | camilamerighi@hotmail.com    |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   14 | Camila Pereira Pinto               | camila_pereira |        1 | 374.904.058-31 | camila.pp6@gmail.com         |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    8 | Caroline Nascimento de Souza       | caroline       |        1 | 325.913.338-07 | krol.nascimento85@gmail.com  |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   13 | Fabio Cabrini                      | fabio          |        1 | 234.480.128-66 | fafe77@yahoo.com             |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    7 | Gisele Alves Guimaraes (Nina)      | gisele         |        1 | 629.942.635-72 | gisadudy@yahoo.com.br        |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   18 | Jéssica Martins Rodrigues da Silva | jessica        |        1 | 480.898.918-29 | jessicamartins2807@gmail.com |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    9 | Juliana Maria Luzzi Franco Ribeiro | juliana        |        1 | 282.017.818-99 | jmlfr@uol.com.br             |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   15 | Lucas Gagliato Uriel Militao       | lucas          |        1 | 470.527.008-83 | lucasgagliatoum@hotmail.com  |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   12 | Miriam Silva                       | miriam         |        1 | 028.379.978-11 | miriam.silva09@gmail.com     |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   10 | Rodolpho dos Santos Moraes         | rodolpho       |        1 | 119.082.487-69 | moraes.rodolpho@gmail.com    |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   19 | Rodrigo Brito                      | rodrigo        |        1 | 271.943.998-30 | britors@live.com             |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |   17 | Solange Severina Lopes (Sophia)    | solange        |        1 | 165.191.238-62 | solangeslopes@yahoo.com.br   |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    5 | Timbere Serpa Nogueira             | timbere        |        1 | 368.683.338-70 | timbere.nog@gmail.com        |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# |    6 | Viviane Ferreira Cerqueira         | viviane        |        1 | 112.231.236-93 | vivianefcerqueira@gmail.com  |
# +------+------------------------------------+----------------+----------+----------------+------------------------------+
# Total de clientes: 17

# %% [markdown]
# ### Inserir um cliente

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
name = 'Maria da Silva'
nickname = 'maria_silva_4'
document = '02063565015'
email = 'maria.silva@example.com'
whatsapp = '13980888788'

print(customers.insert(vendor, nickname, name, document, email, whatsapp))
# Out:
# bad request - Validation failed: item 0: nickname is already in use

# %% [markdown]
# ## Atualizar um cliente

# %%
import customers
# parametros de configuração
vendor = "estudio_amelia"
nickname = "test"
name = ""
document = ""
email = ""
whatsapp = ""
status = "0" # 1 - ativo; 0 - inativo

print(customers.update(1, vendor, nickname, name, document, email, whatsapp, status))
# Out:
# success - Customer updated successfully

# %% [markdown]
# ## Atualizar por um arquivo csv

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
file_path = './customers.csv'
print(customers.insert_csv(vendor, file_path))
# Out:
# Processando linha 1: {'nickname': 'ana_flavia', 'name': 'Ana Flavia de Andrade da Silva', 'document': '', 'email': 'andrade.af22@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 1: bad request - Validation failed: item 0: nickname is already in use
# Processando linha 2: {'nickname': 'camila', 'name': 'Camila Trevizani Merigui', 'document': '', 'email': 'camilamerighi@hotmail.com', 'whatsapp': ''}
# Resposta da API para linha 2: bad request - Validation failed: item 0: nickname is already in use
# Processando linha 3: {'nickname': 'timbere', 'name': 'Timbere Serpa Nogueira', 'document': '368.683.338-70', 'email': 'timbere.nog@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 3: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 4: {'nickname': 'solange', 'name': 'Solange Severina Lopes (Sophia)', 'document': '165.191.238-62', 'email': 'solangeslopes@yahoo.com.br', 'whatsapp': ''}
# Resposta da API para linha 4: success - Customers created successfully
# Processando linha 5: {'nickname': 'viviane', 'name': 'Viviane Ferreira Cerqueira', 'document': '112.231.236-93', 'email': 'vivianefcerqueira@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 5: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 6: {'nickname': 'gisele', 'name': 'Gisele Alves Guimaraes (Nina)', 'document': '629.942.635-72', 'email': 'gisadudy@yahoo.com.br', 'whatsapp': ''}
# Resposta da API para linha 6: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 7: {'nickname': 'caroline', 'name': 'Caroline Nascimento de Souza', 'document': '325.913.338-07', 'email': 'krol.nascimento85@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 7: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 8: {'nickname': 'juliana', 'name': 'Juliana Maria Luzzi Franco Ribeiro', 'document': '282.017.818-99', 'email': 'jmlfr@uol.com.br', 'whatsapp': ''}
# Resposta da API para linha 8: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 9: {'nickname': 'rodolpho', 'name': 'Rodolpho dos Santos Moraes', 'document': '119.082.487-69', 'email': 'moraes.rodolpho@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 9: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 10: {'nickname': 'andrea', 'name': 'Andrea Silva', 'document': '300.700.538-80', 'email': 'andrea-psico@hotmail.com', 'whatsapp': ''}
# Resposta da API para linha 10: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 11: {'nickname': 'miriam', 'name': 'Miriam Silva', 'document': '028.379.978-11', 'email': 'miriam.silva09@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 11: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 12: {'nickname': 'fabio', 'name': 'Fabio Cabrini', 'document': '234.480.128-66', 'email': 'fafe77@yahoo.com', 'whatsapp': ''}
# Resposta da API para linha 12: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 13: {'nickname': 'camila_pereira', 'name': 'Camila Pereira Pinto', 'document': '374.904.058-31', 'email': 'camila.pp6@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 13: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 14: {'nickname': 'lucas', 'name': 'Lucas Gagliato Uriel Militao', 'document': '470.527.008-83', 'email': 'lucasgagliatoum@hotmail.com', 'whatsapp': ''}
# Resposta da API para linha 14: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 15: {'nickname': 'alessandra', 'name': 'Alessandra Dias Galassi', 'document': '152.719.708-50', 'email': 'alegalassi7@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 15: bad request - Validation failed: item 0: nickname is already in use; document is already in use
# Processando linha 16: {'nickname': 'jessica', 'name': 'Jéssica Martins Rodrigues da Silva', 'document': '480.898.918-29', 'email': 'jessicamartins2807@gmail.com', 'whatsapp': ''}
# Resposta da API para linha 16: success - Customers created successfully
# Processando linha 17: {'nickname': 'rodrigo', 'name': 'Rodrigo Brito', 'document': '271.943.998-30', 'email': 'britors@live.com', 'whatsapp': ''}
# Resposta da API para linha 17: success - Customers created successfully
# success - Customers created successfully
