# %% [markdown]
# ## Clientes
#
# Rotinas de manutenção de clientes

# %% [markdown]
# ### Consultar clientes

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
status = "" # 1 - ativos; 0 - inativos; "" - todos, 
nickname = ''
name = ''
document = ''
email = ''
whatsapp = ''

print(customers.get(vendor, status, nickname, name, document, email, whatsapp))
# Out:
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |   id | name           | nickname      |   status | document       | email                   | whatsapp        |
# +======+================+===============+==========+================+=========================+=================+
# |    2 | Maria da Silva | maria_silva_4 |        1 | 020.635.650-15 | maria.silva@example.com | (13) 98088-8788 |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+
# |    1 | ola            | test          |        1 | 044.179.328-24 | lavinas@gmail.com       | (11) 98087-6112 |
# +------+----------------+---------------+----------+----------------+-------------------------+-----------------+

# %% [markdown]
# ### Inserir um cliente

# %%
import customers

# parametros de configuração
vendor = 'estudio_amelia'
name = 'Maria da Silva'
nickname = 'maria_silva_4'
document = '02063565015'
email = 'maria.silva@example.com'
whatsapp = '13980888788'

print(customers.insert(vendor, nickname, name, document, email, whatsapp))
# Out:
# success - Customers created successfully

# %% [markdown]
# ## Atualizar um cliente

# %%
import customers
# parametros de configuração
vendor = "estudio_amelia"
nickname = ""
name = ""
document = ""
email = ""
whatsapp = ""
status = "" # 1 - ativo; 0 - inativo

print(customers.update(1, vendor, nickname, name, document, email, whatsapp, status))
# Out:
# error - Validation failed: nickname is required; at least one field must be provided for update
