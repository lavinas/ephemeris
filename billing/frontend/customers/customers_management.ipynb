# %% [markdown]
# ## Clientes
#
# Rotinas de manutenção de clientes

# %% [markdown]
# ### Consultar clientes

# %%
import customers_management as customers

# parametros de configuração
vendor = 'estudio_amelia' # obrigatório
status = '' # 1 - ativos; 0 - inativos; "" - todos, 
nickname = 'alessandra_galassi' # '' - todos
name = '' # '' - todos
document = '' # '' - todos
email = '' # '' - todos
whatsapp = '' # '' - todos

customers_list, customers_count = customers.get(vendor, status, nickname, name, document, email, whatsapp)

print(customers_list)
print(f"Total de clientes: {customers_count}")
# Out:
# +------+--------------------+--------------------+----------------+-----------------------+----------------+----------+---------------------+---------------------+
# |   id | nickname           | name               | document       | email                 |       whatsapp |   status | created_at          | updated_at          |
# +======+====================+====================+================+=======================+================+==========+=====================+=====================+
# |  158 | alessandra_galassi | Alessandra Galassi | 152.719.708-50 | alegalassi7@gmail.com | +5511972352270 |        1 | 2026-07-03 15:41:16 | 2026-07-26 21:43:50 |
# +------+--------------------+--------------------+----------------+-----------------------+----------------+----------+---------------------+---------------------+
# Total de clientes: 1

# %% [markdown]
# ### Inserir um cliente

# %%
import customers_management as customers

# parametros de configuração
vendor = 'estudio_amelia'
name = 'Juliana de Araujo Teixeira'
nickname = 'juliana_teixeira'
document = '277.275.018-32'
email = 'ju.jat@hotmail.com'
whatsapp = '11 99256-6166'

print(customers.insert(vendor, nickname, name, document, email, whatsapp))
# Out:
# success - Customers created successfully

# %% [markdown]
# ## Atualizar um cliente

# %%
import customers_management as customers

# parametros de configuração
vendor = "estudio_amelia"
nickname = "alessandra_galassi"
name = ""
document = ""
email = "alegalassi7@gmail.com"
whatsapp = ""
status = "" # 1 - ativo; 0 - inativo

# "alegalassi7@gmail.com"

print(customers.update(1, vendor, nickname, name, document, email, whatsapp, status))
# Out:
# success - Customer updated successfully

# %% [markdown]
# ## Atualizar por um arquivo csv

# %%
import customers_management as customers

# parametros de configuração
vendor = 'estudio_amelia'
file_path = './customers.csv'
print(customers.insert_csv(vendor, file_path))
# Out:
# Processando linha 1: {'nickname': 'alessandra_galassi', 'name': 'Alessandra Dias Galassi', 'document': '152.719.708-50', 'email': 'alegalassi7@gmail.com', 'whatsapp': '(11) 97235-2270'}
# Resposta da API para linha 1: success - Customers created successfully
# Processando linha 2: {'nickname': 'ana_flavia', 'name': 'Ana Flavia de Andrade da Silva', 'document': '381.793.318-57', 'email': 'andrade.af22@gmail.com', 'whatsapp': '(11) 97203-7724'}
# Resposta da API para linha 2: success - Customers created successfully
# Processando linha 3: {'nickname': 'andrea_silva', 'name': 'Andrea Silva', 'document': '300.700.538-80', 'email': 'andrea-psico@hotmail.com', 'whatsapp': '1 (813) 733-9523'}
# Resposta da API para linha 3: success - Customers created successfully
# Processando linha 4: {'nickname': 'camila_merigui', 'name': 'Camila Merigui', 'document': '368.574.718-51', 'email': 'camilamerighi@hotmail.com', 'whatsapp': '(11) 98579-9000'}
# Resposta da API para linha 4: success - Customers created successfully
# Processando linha 5: {'nickname': 'camila_pereira', 'name': 'Camila Pereira Pinto', 'document': '374.904.058-31', 'email': 'camila.pp6@gmail.com', 'whatsapp': '(11) 98121-8255'}
# Resposta da API para linha 5: success - Customers created successfully
# Processando linha 6: {'nickname': 'caroline_souza', 'name': 'Caroline Nascimento de Souza', 'document': '325.913.338-07', 'email': 'krol.nascimento85@gmail.com', 'whatsapp': '(11) 98672-7976'}
# Resposta da API para linha 6: success - Customers created successfully
# Processando linha 7: {'nickname': 'diego_almeida', 'name': 'Diego Guarda De Almeida', 'document': '216.945.878-60', 'email': '', 'whatsapp': '(11) 97592-3666'}
# Resposta da API para linha 7: success - Customers created successfully
# Processando linha 8: {'nickname': 'fabio_cabrini', 'name': 'Fabio Cabrini', 'document': '234.480.128-66', 'email': 'fafe77@yahoo.com', 'whatsapp': '41 76 752-0704'}
# Resposta da API para linha 8: success - Customers created successfully
# Processando linha 9: {'nickname': 'jessica_silva', 'name': 'Jéssica Martins Rodrigues da Silva', 'document': '480.898.918-29', 'email': 'jessicamartins2807@gmail.com', 'whatsapp': '(11) 96120-9077'}
# Resposta da API para linha 9: success - Customers created successfully
# Processando linha 10: {'nickname': 'juliana_ribeiro', 'name': 'Juliana Maria Luzzi Franco Ribeiro', 'document': '282.017.818-99', 'email': 'jmlfr@uol.com.br', 'whatsapp': '(11) 98911-0608'}
# Resposta da API para linha 10: success - Customers created successfully
# Processando linha 11: {'nickname': 'leandro_bauch', 'name': 'Leandro Bauch', 'document': '339.636.848-79', 'email': 'leandro.bauch@mottafernandes.com.br', 'whatsapp': '(11) 99466-0909'}
# Resposta da API para linha 11: success - Customers created successfully
# Processando linha 12: {'nickname': 'lucas_limitao', 'name': 'Lucas Gagliato Uriel Militão', 'document': '470.527.008-83', 'email': 'lucasgagliatoum@hotmail.com', 'whatsapp': '(11) 94714-5890'}
# Resposta da API para linha 12: success - Customers created successfully
# Processando linha 13: {'nickname': 'miriam_silva', 'name': 'Miriam Silva', 'document': '028.379.978-11', 'email': 'miriam.silva09@gmail.com', 'whatsapp': '(11) 96733-2211'}
# Resposta da API para linha 13: success - Customers created successfully
# Processando linha 14: {'nickname': 'rafael_sato', 'name': 'Rafael Yutaka Sato', 'document': '393.072.878-80', 'email': 'rysato0@gmail.com', 'whatsapp': '(11) 97441-8737'}
# Resposta da API para linha 14: success - Customers created successfully
# Processando linha 15: {'nickname': 'rodolpho_moraes', 'name': 'Rodolpho dos Santos Moraes', 'document': '119.082.487-69', 'email': 'moraes.rodolpho@gmail.com', 'whatsapp': '(11) 99782-8550'}
# Resposta da API para linha 15: success - Customers created successfully
# Processando linha 16: {'nickname': 'rodrigo_brito', 'name': 'Rodrigo Brito', 'document': '271.943.998-30', 'email': 'britors@live.com', 'whatsapp': '(13) 99627-3411'}
# Resposta da API para linha 16: success - Customers created successfully
# Processando linha 17: {'nickname': 'rossana_caetano', 'name': 'Rossana Caetano', 'document': '719.077.930-20', 'email': 'rossanacaetano@hormail.com', 'whatsapp': ''}
# Resposta da API para linha 17: success - Customers created successfully
# Processando linha 18: {'nickname': 'rui_faco', 'name': 'Rui Miranda Ribeiro Facó', 'document': '067.035.273-00', 'email': 'rui.mfaco@gmail.com', 'whatsapp': '(85) 99950-0514'}
# Resposta da API para linha 18: success - Customers created successfully
# Processando linha 19: {'nickname': 'solange_lopes', 'name': 'Solange Severina Lopes', 'document': '165.191.238-62', 'email': 'solangeslopes@yahoo.com.br', 'whatsapp': '(11) 97546-3470'}
# Resposta da API para linha 19: success - Customers created successfully
# Processando linha 20: {'nickname': 'timbere', 'name': 'Timbere Serpa Nogueira', 'document': '368.683.338-70', 'email': 'timbere.nog@gmail.com', 'whatsapp': '(11) 94945-4534'}
# Resposta da API para linha 20: success - Customers created successfully
# Processando linha 21: {'nickname': 'viviane_cerqueira', 'name': 'Viviane Ferreira Cerqueira', 'document': '112.231.236-93', 'email': 'vivianefcerqueira@gmail.com', 'whatsapp': '(11) 95551-0238'}
# Resposta da API para linha 21: success - Customers created successfully
# success - Customers created successfully
